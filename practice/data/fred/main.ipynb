# %%
from fred import Fred
from database import Database

import logging
log = logging.getLogger(__name__)

# import os
import time
import random
import pandas as pd

# %%
class FredETL:
    def __init__(self):
        api_key = 'b85eb30e34abc01edd5b64c248bb945b'
        self.fred = Fred(api_key)
        self.db = Database()
        self.metrics = None
        self.datasets = []

        self.gen_metrics()

    def extract(self):
        random_time = random.uniform(0.5, 1.0)

        for _topic,metrics in self.metrics.items():
            if _topic == 'state':
                state = 1
            else:
                state = 0
            
            for id,_desc in metrics.items():
                if state == 1:
                    topic = _desc[1]
                    desc = _desc[0]
                else:
                    topic = _topic
                    desc = _desc

                time.sleep(random_time)
                try:
                    data = pd.DataFrame(self.fred.get_series(id),columns=['metric'])
                    data = data.reset_index(drop=False).rename(columns={'index': 'metric_dt'})
                    data = (
                        data
                        .assign(metric_id=id)
                        .assign(metric_desc=desc)
                        .assign(state_ind=state)
                        .assign(topic=topic)
                    )
                    self.datasets.append(data)
                except:
                    # print(id)
                    pass

    def load(self):
        schema = 'base'
        table = 'fred_metrics_data'
        
        self.db.cur.execute(f'drop table if exists {schema}.{table}')
        self.db.conn.commit()
        
        for df in self.datasets:
            df.head()
            df.to_sql(table,self.db.engine,schema=schema,if_exists='append',index=False)
        
        self.db.close()

    def transform(self):
        None

    def gen_metrics(self):
        us_states = {
            'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ',
            'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO',
            'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL',
            'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID',
            'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
            'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA',
            'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA',
            'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
            'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE',
            'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
            'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC',
            'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
            'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI',
            'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN',
            'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
            'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV',
            'Wisconsin': 'WI', 'Wyoming': 'WY'
        }
        _state_metrics = {
            '{ST}UR': ('unemployment rate - {STATE}','unemployment'),
            'STTMINWG{ST}': ('State Minimum Wage Rate - {STATE}','earnings'),
            '{ST}UCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single Family Residences, Condos, and CO-OPs - {STATE}','housing'),
            '{ST}STHPI': ('All-Transactions House Price Index - {STATE}','housing'),
            '{ST}NQGSP': ('Gross Domestic Product: All Industry Total - {STATE}','gdp'),
            'MEHOINUS{ST}A672N': ('Real Median Household Income - {STATE}','earnings'),
            '{ST}PCPI': ('Per Capita Personal Income - {STATE}','earnings'),
            '{ST}PCE': ('Personal Consumption Expenditures: Total - {STATE}','consumption'),
            '{ST}ERET': ('Retail Trade Earnings - {STATE}','earnings'),
        }

        state_metrics = {}
        for state,st in us_states.items():
            for k,v in _state_metrics.items():
                state_metrics[k.format(ST=st)] = (v[0].format(STATE=state),v[1])
        self.metrics = {
            'unemployment': {
                'UNRATE': 'Unemployment Rate',
                # 'LNS14000006': 'Unemployment Rate - Black or African American',
                # 'CCSA': 'Continued Claims (Insured Unemployment)',
                # 'UEMPMEAN': 'Average Weeks Unemployed',
                # 'LNS14000002': 'Unemployment Rate - Women',
                # 'LNS14000009': 'Unemployment Rate - Hispanic or Latino',
                # 'LNS14000001': 'Unemployment Rate - Men',
                # 'LNS14000003': 'Unemployment Rate - White',
                # 'UEMP27OV': 'Number Unemployed for 27 Weeks & over',
            },
            # 'delinquency': {
            #     'DRCCLACBS': 'Delinquency Rate on Credit Card Loans, All Commercial Banks',
            #     'DRCLACBS': 'Delinquency Rate on Consumer Loans, All Commercial Banks',
            #     'DRALACBS': 'Delinquency Rate on All Loans, All Commercial Banks',
            #     'DRSFRMACBS': 'Delinquency Rate on Single-Family Residential Mortgages, Booked in Domestic Offices, All Commercial Banks',
            #     'DRBLACBS': 'Delinquency Rate on Business Loans, All Commercial Banks',
            #     'DRCRELEXFACBS': 'Delinquency Rate on Commercial Real Estate Loans (Excluding Farmland), Booked in Domestic Offices, All Commercial Banks',
            #     'DRCCLT100S': 'Delinquency Rate on Credit Card Loans, Banks Ranked 1st to 100th Largest in Size by Assets',
            #     'Q09084USQ507NNBR': 'Mortgage Delinquency Rates for United States',
            #     'DRSREACBS': 'Delinquency Rate on Loans Secured by Real Estate, All Commercial Banks',
            # },
            # 'charge off': {
            #     'CORCCACBS': 'Charge-Off Rate on Credit Card Loans, All Commercial Banks',
            #     'CORCCT100S': 'Charge-Off Rate on Credit Card Loans, Banks Ranked 1st to 100th Largest in Size by Assets',
            #     'CORCACBS': 'Charge-Off Rate on Consumer Loans, All Commercial Banks',
            #     'CORCREXFACBS': 'Charge-Off Rate on Commercial Real Estate Loans (Excluding Farmland), Booked in Domestic Offices, All Commercial Banks',
            #     'CORBLACBS': 'Charge-Off Rate on Business Loans, All Commercial Banks',
            #     'CORSREACBS': 'Charge-Off Rate on Loans Secured by Real Estate, All Commercial Banks',
            #     'COROCLACBS': 'Charge-Off Rate on Other Consumer Loans, All Commercial Banks',
            #     'CORCCT100S': 'Charge-Off Rate on Credit Card Loans, Banks Ranked 1st to 100th Largest in Size by Assets',
            # },
            # 'consumption': {
            #     'PCE': 'Personal Consumption Expenditures',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            # 'inflation': {
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            # 'housing': {
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            # 'gdp': {
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            # 'cpi': {
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            # 'm2': {
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            # 'earnings': {
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            #     '____': '____',
            # },
            'state': state_metrics,
        }

# %%
etl = FredETL()

# %%
etl.metrics
# Out:
# {'unemployment': {'UNRATE': 'Unemployment Rate'},
#  'state': {'ALUR': ('unemployment rate - Alabama', 'unemployment'),
#   'STTMINWGAL': ('State Minimum Wage Rate - Alabama', 'earnings'),
#   'ALUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Alabama',
#    'housing'),
#   'ALSTHPI': ('All-Transactions House Price Index - Alabama', 'housing'),
#   'ALNQGSP': ('Gross Domestic Product: All Industry Total - Alabama', 'gdp'),
#   'MEHOINUSALA672N': ('Real Median Household Income - Alabama', 'earnings'),
#   'ALPCPI': ('Per Capita Personal Income - Alabama', 'earnings'),
#   'ALPCE': ('Personal Consumption Expenditures: Total - Alabama',
#    'consumption'),
#   'ALERET': ('Retail Trade Earnings - Alabama', 'earnings'),
#   'AKUR': ('unemployment rate - Alaska', 'unemployment'),
#   'STTMINWGAK': ('State Minimum Wage Rate - Alaska', 'earnings'),
#   'AKUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Alaska',
#    'housing'),
#   'AKSTHPI': ('All-Transactions House Price Index - Alaska', 'housing'),
#   'AKNQGSP': ('Gross Domestic Product: All Industry Total - Alaska', 'gdp'),
#   'MEHOINUSAKA672N': ('Real Median Household Income - Alaska', 'earnings'),
#   'AKPCPI': ('Per Capita Personal Income - Alaska', 'earnings'),
#   'AKPCE': ('Personal Consumption Expenditures: Total - Alaska',
#    'consumption'),
#   'AKERET': ('Retail Trade Earnings - Alaska', 'earnings'),
#   'AZUR': ('unemployment rate - Arizona', 'unemployment'),
#   'STTMINWGAZ': ('State Minimum Wage Rate - Arizona', 'earnings'),
#   'AZUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Arizona',
#    'housing'),
#   'AZSTHPI': ('All-Transactions House Price Index - Arizona', 'housing'),
#   'AZNQGSP': ('Gross Domestic Product: All Industry Total - Arizona', 'gdp'),
#   'MEHOINUSAZA672N': ('Real Median Household Income - Arizona', 'earnings'),
#   'AZPCPI': ('Per Capita Personal Income - Arizona', 'earnings'),
#   'AZPCE': ('Personal Consumption Expenditures: Total - Arizona',
#    'consumption'),
#   'AZERET': ('Retail Trade Earnings - Arizona', 'earnings'),
#   'ARUR': ('unemployment rate - Arkansas', 'unemployment'),
#   'STTMINWGAR': ('State Minimum Wage Rate - Arkansas', 'earnings'),
#   'ARUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Arkansas',
#    'housing'),
#   'ARSTHPI': ('All-Transactions House Price Index - Arkansas', 'housing'),
#   'ARNQGSP': ('Gross Domestic Product: All Industry Total - Arkansas', 'gdp'),
#   'MEHOINUSARA672N': ('Real Median Household Income - Arkansas', 'earnings'),
#   'ARPCPI': ('Per Capita Personal Income - Arkansas', 'earnings'),
#   'ARPCE': ('Personal Consumption Expenditures: Total - Arkansas',
#    'consumption'),
#   'ARERET': ('Retail Trade Earnings - Arkansas', 'earnings'),
#   'CAUR': ('unemployment rate - California', 'unemployment'),
#   'STTMINWGCA': ('State Minimum Wage Rate - California', 'earnings'),
#   'CAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - California',
#    'housing'),
#   'CASTHPI': ('All-Transactions House Price Index - California', 'housing'),
#   'CANQGSP': ('Gross Domestic Product: All Industry Total - California',
#    'gdp'),
#   'MEHOINUSCAA672N': ('Real Median Household Income - California', 'earnings'),
#   'CAPCPI': ('Per Capita Personal Income - California', 'earnings'),
#   'CAPCE': ('Personal Consumption Expenditures: Total - California',
#    'consumption'),
#   'CAERET': ('Retail Trade Earnings - California', 'earnings'),
#   'COUR': ('unemployment rate - Colorado', 'unemployment'),
#   'STTMINWGCO': ('State Minimum Wage Rate - Colorado', 'earnings'),
#   'COUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Colorado',
#    'housing'),
#   'COSTHPI': ('All-Transactions House Price Index - Colorado', 'housing'),
#   'CONQGSP': ('Gross Domestic Product: All Industry Total - Colorado', 'gdp'),
#   'MEHOINUSCOA672N': ('Real Median Household Income - Colorado', 'earnings'),
#   'COPCPI': ('Per Capita Personal Income - Colorado', 'earnings'),
#   'COPCE': ('Personal Consumption Expenditures: Total - Colorado',
#    'consumption'),
#   'COERET': ('Retail Trade Earnings - Colorado', 'earnings'),
#   'CTUR': ('unemployment rate - Connecticut', 'unemployment'),
#   'STTMINWGCT': ('State Minimum Wage Rate - Connecticut', 'earnings'),
#   'CTUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Connecticut',
#    'housing'),
#   'CTSTHPI': ('All-Transactions House Price Index - Connecticut', 'housing'),
#   'CTNQGSP': ('Gross Domestic Product: All Industry Total - Connecticut',
#    'gdp'),
#   'MEHOINUSCTA672N': ('Real Median Household Income - Connecticut',
#    'earnings'),
#   'CTPCPI': ('Per Capita Personal Income - Connecticut', 'earnings'),
#   'CTPCE': ('Personal Consumption Expenditures: Total - Connecticut',
#    'consumption'),
#   'CTERET': ('Retail Trade Earnings - Connecticut', 'earnings'),
#   'DEUR': ('unemployment rate - Delaware', 'unemployment'),
#   'STTMINWGDE': ('State Minimum Wage Rate - Delaware', 'earnings'),
#   'DEUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Delaware',
#    'housing'),
#   'DESTHPI': ('All-Transactions House Price Index - Delaware', 'housing'),
#   'DENQGSP': ('Gross Domestic Product: All Industry Total - Delaware', 'gdp'),
#   'MEHOINUSDEA672N': ('Real Median Household Income - Delaware', 'earnings'),
#   'DEPCPI': ('Per Capita Personal Income - Delaware', 'earnings'),
#   'DEPCE': ('Personal Consumption Expenditures: Total - Delaware',
#    'consumption'),
#   'DEERET': ('Retail Trade Earnings - Delaware', 'earnings'),
#   'FLUR': ('unemployment rate - Florida', 'unemployment'),
#   'STTMINWGFL': ('State Minimum Wage Rate - Florida', 'earnings'),
#   'FLUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Florida',
#    'housing'),
#   'FLSTHPI': ('All-Transactions House Price Index - Florida', 'housing'),
#   'FLNQGSP': ('Gross Domestic Product: All Industry Total - Florida', 'gdp'),
#   'MEHOINUSFLA672N': ('Real Median Household Income - Florida', 'earnings'),
#   'FLPCPI': ('Per Capita Personal Income - Florida', 'earnings'),
#   'FLPCE': ('Personal Consumption Expenditures: Total - Florida',
#    'consumption'),
#   'FLERET': ('Retail Trade Earnings - Florida', 'earnings'),
#   'GAUR': ('unemployment rate - Georgia', 'unemployment'),
#   'STTMINWGGA': ('State Minimum Wage Rate - Georgia', 'earnings'),
#   'GAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Georgia',
#    'housing'),
#   'GASTHPI': ('All-Transactions House Price Index - Georgia', 'housing'),
#   'GANQGSP': ('Gross Domestic Product: All Industry Total - Georgia', 'gdp'),
#   'MEHOINUSGAA672N': ('Real Median Household Income - Georgia', 'earnings'),
#   'GAPCPI': ('Per Capita Personal Income - Georgia', 'earnings'),
#   'GAPCE': ('Personal Consumption Expenditures: Total - Georgia',
#    'consumption'),
#   'GAERET': ('Retail Trade Earnings - Georgia', 'earnings'),
#   'HIUR': ('unemployment rate - Hawaii', 'unemployment'),
#   'STTMINWGHI': ('State Minimum Wage Rate - Hawaii', 'earnings'),
#   'HIUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Hawaii',
#    'housing'),
#   'HISTHPI': ('All-Transactions House Price Index - Hawaii', 'housing'),
#   'HINQGSP': ('Gross Domestic Product: All Industry Total - Hawaii', 'gdp'),
#   'MEHOINUSHIA672N': ('Real Median Household Income - Hawaii', 'earnings'),
#   'HIPCPI': ('Per Capita Personal Income - Hawaii', 'earnings'),
#   'HIPCE': ('Personal Consumption Expenditures: Total - Hawaii',
#    'consumption'),
#   'HIERET': ('Retail Trade Earnings - Hawaii', 'earnings'),
#   'IDUR': ('unemployment rate - Idaho', 'unemployment'),
#   'STTMINWGID': ('State Minimum Wage Rate - Idaho', 'earnings'),
#   'IDUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Idaho',
#    'housing'),
#   'IDSTHPI': ('All-Transactions House Price Index - Idaho', 'housing'),
#   'IDNQGSP': ('Gross Domestic Product: All Industry Total - Idaho', 'gdp'),
#   'MEHOINUSIDA672N': ('Real Median Household Income - Idaho', 'earnings'),
#   'IDPCPI': ('Per Capita Personal Income - Idaho', 'earnings'),
#   'IDPCE': ('Personal Consumption Expenditures: Total - Idaho', 'consumption'),
#   'IDERET': ('Retail Trade Earnings - Idaho', 'earnings'),
#   'ILUR': ('unemployment rate - Illinois', 'unemployment'),
#   'STTMINWGIL': ('State Minimum Wage Rate - Illinois', 'earnings'),
#   'ILUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Illinois',
#    'housing'),
#   'ILSTHPI': ('All-Transactions House Price Index - Illinois', 'housing'),
#   'ILNQGSP': ('Gross Domestic Product: All Industry Total - Illinois', 'gdp'),
#   'MEHOINUSILA672N': ('Real Median Household Income - Illinois', 'earnings'),
#   'ILPCPI': ('Per Capita Personal Income - Illinois', 'earnings'),
#   'ILPCE': ('Personal Consumption Expenditures: Total - Illinois',
#    'consumption'),
#   'ILERET': ('Retail Trade Earnings - Illinois', 'earnings'),
#   'INUR': ('unemployment rate - Indiana', 'unemployment'),
#   'STTMINWGIN': ('State Minimum Wage Rate - Indiana', 'earnings'),
#   'INUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Indiana',
#    'housing'),
#   'INSTHPI': ('All-Transactions House Price Index - Indiana', 'housing'),
#   'INNQGSP': ('Gross Domestic Product: All Industry Total - Indiana', 'gdp'),
#   'MEHOINUSINA672N': ('Real Median Household Income - Indiana', 'earnings'),
#   'INPCPI': ('Per Capita Personal Income - Indiana', 'earnings'),
#   'INPCE': ('Personal Consumption Expenditures: Total - Indiana',
#    'consumption'),
#   'INERET': ('Retail Trade Earnings - Indiana', 'earnings'),
#   'IAUR': ('unemployment rate - Iowa', 'unemployment'),
#   'STTMINWGIA': ('State Minimum Wage Rate - Iowa', 'earnings'),
#   'IAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Iowa',
#    'housing'),
#   'IASTHPI': ('All-Transactions House Price Index - Iowa', 'housing'),
#   'IANQGSP': ('Gross Domestic Product: All Industry Total - Iowa', 'gdp'),
#   'MEHOINUSIAA672N': ('Real Median Household Income - Iowa', 'earnings'),
#   'IAPCPI': ('Per Capita Personal Income - Iowa', 'earnings'),
#   'IAPCE': ('Personal Consumption Expenditures: Total - Iowa', 'consumption'),
#   'IAERET': ('Retail Trade Earnings - Iowa', 'earnings'),
#   'KSUR': ('unemployment rate - Kansas', 'unemployment'),
#   'STTMINWGKS': ('State Minimum Wage Rate - Kansas', 'earnings'),
#   'KSUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Kansas',
#    'housing'),
#   'KSSTHPI': ('All-Transactions House Price Index - Kansas', 'housing'),
#   'KSNQGSP': ('Gross Domestic Product: All Industry Total - Kansas', 'gdp'),
#   'MEHOINUSKSA672N': ('Real Median Household Income - Kansas', 'earnings'),
#   'KSPCPI': ('Per Capita Personal Income - Kansas', 'earnings'),
#   'KSPCE': ('Personal Consumption Expenditures: Total - Kansas',
#    'consumption'),
#   'KSERET': ('Retail Trade Earnings - Kansas', 'earnings'),
#   'KYUR': ('unemployment rate - Kentucky', 'unemployment'),
#   'STTMINWGKY': ('State Minimum Wage Rate - Kentucky', 'earnings'),
#   'KYUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Kentucky',
#    'housing'),
#   'KYSTHPI': ('All-Transactions House Price Index - Kentucky', 'housing'),
#   'KYNQGSP': ('Gross Domestic Product: All Industry Total - Kentucky', 'gdp'),
#   'MEHOINUSKYA672N': ('Real Median Household Income - Kentucky', 'earnings'),
#   'KYPCPI': ('Per Capita Personal Income - Kentucky', 'earnings'),
#   'KYPCE': ('Personal Consumption Expenditures: Total - Kentucky',
#    'consumption'),
#   'KYERET': ('Retail Trade Earnings - Kentucky', 'earnings'),
#   'LAUR': ('unemployment rate - Louisiana', 'unemployment'),
#   'STTMINWGLA': ('State Minimum Wage Rate - Louisiana', 'earnings'),
#   'LAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Louisiana',
#    'housing'),
#   'LASTHPI': ('All-Transactions House Price Index - Louisiana', 'housing'),
#   'LANQGSP': ('Gross Domestic Product: All Industry Total - Louisiana', 'gdp'),
#   'MEHOINUSLAA672N': ('Real Median Household Income - Louisiana', 'earnings'),
#   'LAPCPI': ('Per Capita Personal Income - Louisiana', 'earnings'),
#   'LAPCE': ('Personal Consumption Expenditures: Total - Louisiana',
#    'consumption'),
#   'LAERET': ('Retail Trade Earnings - Louisiana', 'earnings'),
#   'MEUR': ('unemployment rate - Maine', 'unemployment'),
#   'STTMINWGME': ('State Minimum Wage Rate - Maine', 'earnings'),
#   'MEUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Maine',
#    'housing'),
#   'MESTHPI': ('All-Transactions House Price Index - Maine', 'housing'),
#   'MENQGSP': ('Gross Domestic Product: All Industry Total - Maine', 'gdp'),
#   'MEHOINUSMEA672N': ('Real Median Household Income - Maine', 'earnings'),
#   'MEPCPI': ('Per Capita Personal Income - Maine', 'earnings'),
#   'MEPCE': ('Personal Consumption Expenditures: Total - Maine', 'consumption'),
#   'MEERET': ('Retail Trade Earnings - Maine', 'earnings'),
#   'MDUR': ('unemployment rate - Maryland', 'unemployment'),
#   'STTMINWGMD': ('State Minimum Wage Rate - Maryland', 'earnings'),
#   'MDUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Maryland',
#    'housing'),
#   'MDSTHPI': ('All-Transactions House Price Index - Maryland', 'housing'),
#   'MDNQGSP': ('Gross Domestic Product: All Industry Total - Maryland', 'gdp'),
#   'MEHOINUSMDA672N': ('Real Median Household Income - Maryland', 'earnings'),
#   'MDPCPI': ('Per Capita Personal Income - Maryland', 'earnings'),
#   'MDPCE': ('Personal Consumption Expenditures: Total - Maryland',
#    'consumption'),
#   'MDERET': ('Retail Trade Earnings - Maryland', 'earnings'),
#   'MAUR': ('unemployment rate - Massachusetts', 'unemployment'),
#   'STTMINWGMA': ('State Minimum Wage Rate - Massachusetts', 'earnings'),
#   'MAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Massachusetts',
#    'housing'),
#   'MASTHPI': ('All-Transactions House Price Index - Massachusetts', 'housing'),
#   'MANQGSP': ('Gross Domestic Product: All Industry Total - Massachusetts',
#    'gdp'),
#   'MEHOINUSMAA672N': ('Real Median Household Income - Massachusetts',
#    'earnings'),
#   'MAPCPI': ('Per Capita Personal Income - Massachusetts', 'earnings'),
#   'MAPCE': ('Personal Consumption Expenditures: Total - Massachusetts',
#    'consumption'),
#   'MAERET': ('Retail Trade Earnings - Massachusetts', 'earnings'),
#   'MIUR': ('unemployment rate - Michigan', 'unemployment'),
#   'STTMINWGMI': ('State Minimum Wage Rate - Michigan', 'earnings'),
#   'MIUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Michigan',
#    'housing'),
#   'MISTHPI': ('All-Transactions House Price Index - Michigan', 'housing'),
#   'MINQGSP': ('Gross Domestic Product: All Industry Total - Michigan', 'gdp'),
#   'MEHOINUSMIA672N': ('Real Median Household Income - Michigan', 'earnings'),
#   'MIPCPI': ('Per Capita Personal Income - Michigan', 'earnings'),
#   'MIPCE': ('Personal Consumption Expenditures: Total - Michigan',
#    'consumption'),
#   'MIERET': ('Retail Trade Earnings - Michigan', 'earnings'),
#   'MNUR': ('unemployment rate - Minnesota', 'unemployment'),
#   'STTMINWGMN': ('State Minimum Wage Rate - Minnesota', 'earnings'),
#   'MNUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Minnesota',
#    'housing'),
#   'MNSTHPI': ('All-Transactions House Price Index - Minnesota', 'housing'),
#   'MNNQGSP': ('Gross Domestic Product: All Industry Total - Minnesota', 'gdp'),
#   'MEHOINUSMNA672N': ('Real Median Household Income - Minnesota', 'earnings'),
#   'MNPCPI': ('Per Capita Personal Income - Minnesota', 'earnings'),
#   'MNPCE': ('Personal Consumption Expenditures: Total - Minnesota',
#    'consumption'),
#   'MNERET': ('Retail Trade Earnings - Minnesota', 'earnings'),
#   'MSUR': ('unemployment rate - Mississippi', 'unemployment'),
#   'STTMINWGMS': ('State Minimum Wage Rate - Mississippi', 'earnings'),
#   'MSUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Mississippi',
#    'housing'),
#   'MSSTHPI': ('All-Transactions House Price Index - Mississippi', 'housing'),
#   'MSNQGSP': ('Gross Domestic Product: All Industry Total - Mississippi',
#    'gdp'),
#   'MEHOINUSMSA672N': ('Real Median Household Income - Mississippi',
#    'earnings'),
#   'MSPCPI': ('Per Capita Personal Income - Mississippi', 'earnings'),
#   'MSPCE': ('Personal Consumption Expenditures: Total - Mississippi',
#    'consumption'),
#   'MSERET': ('Retail Trade Earnings - Mississippi', 'earnings'),
#   'MOUR': ('unemployment rate - Missouri', 'unemployment'),
#   'STTMINWGMO': ('State Minimum Wage Rate - Missouri', 'earnings'),
#   'MOUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Missouri',
#    'housing'),
#   'MOSTHPI': ('All-Transactions House Price Index - Missouri', 'housing'),
#   'MONQGSP': ('Gross Domestic Product: All Industry Total - Missouri', 'gdp'),
#   'MEHOINUSMOA672N': ('Real Median Household Income - Missouri', 'earnings'),
#   'MOPCPI': ('Per Capita Personal Income - Missouri', 'earnings'),
#   'MOPCE': ('Personal Consumption Expenditures: Total - Missouri',
#    'consumption'),
#   'MOERET': ('Retail Trade Earnings - Missouri', 'earnings'),
#   'MTUR': ('unemployment rate - Montana', 'unemployment'),
#   'STTMINWGMT': ('State Minimum Wage Rate - Montana', 'earnings'),
#   'MTUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Montana',
#    'housing'),
#   'MTSTHPI': ('All-Transactions House Price Index - Montana', 'housing'),
#   'MTNQGSP': ('Gross Domestic Product: All Industry Total - Montana', 'gdp'),
#   'MEHOINUSMTA672N': ('Real Median Household Income - Montana', 'earnings'),
#   'MTPCPI': ('Per Capita Personal Income - Montana', 'earnings'),
#   'MTPCE': ('Personal Consumption Expenditures: Total - Montana',
#    'consumption'),
#   'MTERET': ('Retail Trade Earnings - Montana', 'earnings'),
#   'NEUR': ('unemployment rate - Nebraska', 'unemployment'),
#   'STTMINWGNE': ('State Minimum Wage Rate - Nebraska', 'earnings'),
#   'NEUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Nebraska',
#    'housing'),
#   'NESTHPI': ('All-Transactions House Price Index - Nebraska', 'housing'),
#   'NENQGSP': ('Gross Domestic Product: All Industry Total - Nebraska', 'gdp'),
#   'MEHOINUSNEA672N': ('Real Median Household Income - Nebraska', 'earnings'),
#   'NEPCPI': ('Per Capita Personal Income - Nebraska', 'earnings'),
#   'NEPCE': ('Personal Consumption Expenditures: Total - Nebraska',
#    'consumption'),
#   'NEERET': ('Retail Trade Earnings - Nebraska', 'earnings'),
#   'NVUR': ('unemployment rate - Nevada', 'unemployment'),
#   'STTMINWGNV': ('State Minimum Wage Rate - Nevada', 'earnings'),
#   'NVUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Nevada',
#    'housing'),
#   'NVSTHPI': ('All-Transactions House Price Index - Nevada', 'housing'),
#   'NVNQGSP': ('Gross Domestic Product: All Industry Total - Nevada', 'gdp'),
#   'MEHOINUSNVA672N': ('Real Median Household Income - Nevada', 'earnings'),
#   'NVPCPI': ('Per Capita Personal Income - Nevada', 'earnings'),
#   'NVPCE': ('Personal Consumption Expenditures: Total - Nevada',
#    'consumption'),
#   'NVERET': ('Retail Trade Earnings - Nevada', 'earnings'),
#   'NHUR': ('unemployment rate - New Hampshire', 'unemployment'),
#   'STTMINWGNH': ('State Minimum Wage Rate - New Hampshire', 'earnings'),
#   'NHUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - New Hampshire',
#    'housing'),
#   'NHSTHPI': ('All-Transactions House Price Index - New Hampshire', 'housing'),
#   'NHNQGSP': ('Gross Domestic Product: All Industry Total - New Hampshire',
#    'gdp'),
#   'MEHOINUSNHA672N': ('Real Median Household Income - New Hampshire',
#    'earnings'),
#   'NHPCPI': ('Per Capita Personal Income - New Hampshire', 'earnings'),
#   'NHPCE': ('Personal Consumption Expenditures: Total - New Hampshire',
#    'consumption'),
#   'NHERET': ('Retail Trade Earnings - New Hampshire', 'earnings'),
#   'NJUR': ('unemployment rate - New Jersey', 'unemployment'),
#   'STTMINWGNJ': ('State Minimum Wage Rate - New Jersey', 'earnings'),
#   'NJUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - New Jersey',
#    'housing'),
#   'NJSTHPI': ('All-Transactions House Price Index - New Jersey', 'housing'),
#   'NJNQGSP': ('Gross Domestic Product: All Industry Total - New Jersey',
#    'gdp'),
#   'MEHOINUSNJA672N': ('Real Median Household Income - New Jersey', 'earnings'),
#   'NJPCPI': ('Per Capita Personal Income - New Jersey', 'earnings'),
#   'NJPCE': ('Personal Consumption Expenditures: Total - New Jersey',
#    'consumption'),
#   'NJERET': ('Retail Trade Earnings - New Jersey', 'earnings'),
#   'NMUR': ('unemployment rate - New Mexico', 'unemployment'),
#   'STTMINWGNM': ('State Minimum Wage Rate - New Mexico', 'earnings'),
#   'NMUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - New Mexico',
#    'housing'),
#   'NMSTHPI': ('All-Transactions House Price Index - New Mexico', 'housing'),
#   'NMNQGSP': ('Gross Domestic Product: All Industry Total - New Mexico',
#    'gdp'),
#   'MEHOINUSNMA672N': ('Real Median Household Income - New Mexico', 'earnings'),
#   'NMPCPI': ('Per Capita Personal Income - New Mexico', 'earnings'),
#   'NMPCE': ('Personal Consumption Expenditures: Total - New Mexico',
#    'consumption'),
#   'NMERET': ('Retail Trade Earnings - New Mexico', 'earnings'),
#   'NYUR': ('unemployment rate - New York', 'unemployment'),
#   'STTMINWGNY': ('State Minimum Wage Rate - New York', 'earnings'),
#   'NYUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - New York',
#    'housing'),
#   'NYSTHPI': ('All-Transactions House Price Index - New York', 'housing'),
#   'NYNQGSP': ('Gross Domestic Product: All Industry Total - New York', 'gdp'),
#   'MEHOINUSNYA672N': ('Real Median Household Income - New York', 'earnings'),
#   'NYPCPI': ('Per Capita Personal Income - New York', 'earnings'),
#   'NYPCE': ('Personal Consumption Expenditures: Total - New York',
#    'consumption'),
#   'NYERET': ('Retail Trade Earnings - New York', 'earnings'),
#   'NCUR': ('unemployment rate - North Carolina', 'unemployment'),
#   'STTMINWGNC': ('State Minimum Wage Rate - North Carolina', 'earnings'),
#   'NCUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - North Carolina',
#    'housing'),
#   'NCSTHPI': ('All-Transactions House Price Index - North Carolina',
#    'housing'),
#   'NCNQGSP': ('Gross Domestic Product: All Industry Total - North Carolina',
#    'gdp'),
#   'MEHOINUSNCA672N': ('Real Median Household Income - North Carolina',
#    'earnings'),
#   'NCPCPI': ('Per Capita Personal Income - North Carolina', 'earnings'),
#   'NCPCE': ('Personal Consumption Expenditures: Total - North Carolina',
#    'consumption'),
#   'NCERET': ('Retail Trade Earnings - North Carolina', 'earnings'),
#   'NDUR': ('unemployment rate - North Dakota', 'unemployment'),
#   'STTMINWGND': ('State Minimum Wage Rate - North Dakota', 'earnings'),
#   'NDUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - North Dakota',
#    'housing'),
#   'NDSTHPI': ('All-Transactions House Price Index - North Dakota', 'housing'),
#   'NDNQGSP': ('Gross Domestic Product: All Industry Total - North Dakota',
#    'gdp'),
#   'MEHOINUSNDA672N': ('Real Median Household Income - North Dakota',
#    'earnings'),
#   'NDPCPI': ('Per Capita Personal Income - North Dakota', 'earnings'),
#   'NDPCE': ('Personal Consumption Expenditures: Total - North Dakota',
#    'consumption'),
#   'NDERET': ('Retail Trade Earnings - North Dakota', 'earnings'),
#   'OHUR': ('unemployment rate - Ohio', 'unemployment'),
#   'STTMINWGOH': ('State Minimum Wage Rate - Ohio', 'earnings'),
#   'OHUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Ohio',
#    'housing'),
#   'OHSTHPI': ('All-Transactions House Price Index - Ohio', 'housing'),
#   'OHNQGSP': ('Gross Domestic Product: All Industry Total - Ohio', 'gdp'),
#   'MEHOINUSOHA672N': ('Real Median Household Income - Ohio', 'earnings'),
#   'OHPCPI': ('Per Capita Personal Income - Ohio', 'earnings'),
#   'OHPCE': ('Personal Consumption Expenditures: Total - Ohio', 'consumption'),
#   'OHERET': ('Retail Trade Earnings - Ohio', 'earnings'),
#   'OKUR': ('unemployment rate - Oklahoma', 'unemployment'),
#   'STTMINWGOK': ('State Minimum Wage Rate - Oklahoma', 'earnings'),
#   'OKUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Oklahoma',
#    'housing'),
#   'OKSTHPI': ('All-Transactions House Price Index - Oklahoma', 'housing'),
#   'OKNQGSP': ('Gross Domestic Product: All Industry Total - Oklahoma', 'gdp'),
#   'MEHOINUSOKA672N': ('Real Median Household Income - Oklahoma', 'earnings'),
#   'OKPCPI': ('Per Capita Personal Income - Oklahoma', 'earnings'),
#   'OKPCE': ('Personal Consumption Expenditures: Total - Oklahoma',
#    'consumption'),
#   'OKERET': ('Retail Trade Earnings - Oklahoma', 'earnings'),
#   'ORUR': ('unemployment rate - Oregon', 'unemployment'),
#   'STTMINWGOR': ('State Minimum Wage Rate - Oregon', 'earnings'),
#   'ORUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Oregon',
#    'housing'),
#   'ORSTHPI': ('All-Transactions House Price Index - Oregon', 'housing'),
#   'ORNQGSP': ('Gross Domestic Product: All Industry Total - Oregon', 'gdp'),
#   'MEHOINUSORA672N': ('Real Median Household Income - Oregon', 'earnings'),
#   'ORPCPI': ('Per Capita Personal Income - Oregon', 'earnings'),
#   'ORPCE': ('Personal Consumption Expenditures: Total - Oregon',
#    'consumption'),
#   'ORERET': ('Retail Trade Earnings - Oregon', 'earnings'),
#   'PAUR': ('unemployment rate - Pennsylvania', 'unemployment'),
#   'STTMINWGPA': ('State Minimum Wage Rate - Pennsylvania', 'earnings'),
#   'PAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Pennsylvania',
#    'housing'),
#   'PASTHPI': ('All-Transactions House Price Index - Pennsylvania', 'housing'),
#   'PANQGSP': ('Gross Domestic Product: All Industry Total - Pennsylvania',
#    'gdp'),
#   'MEHOINUSPAA672N': ('Real Median Household Income - Pennsylvania',
#    'earnings'),
#   'PAPCPI': ('Per Capita Personal Income - Pennsylvania', 'earnings'),
#   'PAPCE': ('Personal Consumption Expenditures: Total - Pennsylvania',
#    'consumption'),
#   'PAERET': ('Retail Trade Earnings - Pennsylvania', 'earnings'),
#   'RIUR': ('unemployment rate - Rhode Island', 'unemployment'),
#   'STTMINWGRI': ('State Minimum Wage Rate - Rhode Island', 'earnings'),
#   'RIUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Rhode Island',
#    'housing'),
#   'RISTHPI': ('All-Transactions House Price Index - Rhode Island', 'housing'),
#   'RINQGSP': ('Gross Domestic Product: All Industry Total - Rhode Island',
#    'gdp'),
#   'MEHOINUSRIA672N': ('Real Median Household Income - Rhode Island',
#    'earnings'),
#   'RIPCPI': ('Per Capita Personal Income - Rhode Island', 'earnings'),
#   'RIPCE': ('Personal Consumption Expenditures: Total - Rhode Island',
#    'consumption'),
#   'RIERET': ('Retail Trade Earnings - Rhode Island', 'earnings'),
#   'SCUR': ('unemployment rate - South Carolina', 'unemployment'),
#   'STTMINWGSC': ('State Minimum Wage Rate - South Carolina', 'earnings'),
#   'SCUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - South Carolina',
#    'housing'),
#   'SCSTHPI': ('All-Transactions House Price Index - South Carolina',
#    'housing'),
#   'SCNQGSP': ('Gross Domestic Product: All Industry Total - South Carolina',
#    'gdp'),
#   'MEHOINUSSCA672N': ('Real Median Household Income - South Carolina',
#    'earnings'),
#   'SCPCPI': ('Per Capita Personal Income - South Carolina', 'earnings'),
#   'SCPCE': ('Personal Consumption Expenditures: Total - South Carolina',
#    'consumption'),
#   'SCERET': ('Retail Trade Earnings - South Carolina', 'earnings'),
#   'SDUR': ('unemployment rate - South Dakota', 'unemployment'),
#   'STTMINWGSD': ('State Minimum Wage Rate - South Dakota', 'earnings'),
#   'SDUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - South Dakota',
#    'housing'),
#   'SDSTHPI': ('All-Transactions House Price Index - South Dakota', 'housing'),
#   'SDNQGSP': ('Gross Domestic Product: All Industry Total - South Dakota',
#    'gdp'),
#   'MEHOINUSSDA672N': ('Real Median Household Income - South Dakota',
#    'earnings'),
#   'SDPCPI': ('Per Capita Personal Income - South Dakota', 'earnings'),
#   'SDPCE': ('Personal Consumption Expenditures: Total - South Dakota',
#    'consumption'),
#   'SDERET': ('Retail Trade Earnings - South Dakota', 'earnings'),
#   'TNUR': ('unemployment rate - Tennessee', 'unemployment'),
#   'STTMINWGTN': ('State Minimum Wage Rate - Tennessee', 'earnings'),
#   'TNUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Tennessee',
#    'housing'),
#   'TNSTHPI': ('All-Transactions House Price Index - Tennessee', 'housing'),
#   'TNNQGSP': ('Gross Domestic Product: All Industry Total - Tennessee', 'gdp'),
#   'MEHOINUSTNA672N': ('Real Median Household Income - Tennessee', 'earnings'),
#   'TNPCPI': ('Per Capita Personal Income - Tennessee', 'earnings'),
#   'TNPCE': ('Personal Consumption Expenditures: Total - Tennessee',
#    'consumption'),
#   'TNERET': ('Retail Trade Earnings - Tennessee', 'earnings'),
#   'TXUR': ('unemployment rate - Texas', 'unemployment'),
#   'STTMINWGTX': ('State Minimum Wage Rate - Texas', 'earnings'),
#   'TXUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Texas',
#    'housing'),
#   'TXSTHPI': ('All-Transactions House Price Index - Texas', 'housing'),
#   'TXNQGSP': ('Gross Domestic Product: All Industry Total - Texas', 'gdp'),
#   'MEHOINUSTXA672N': ('Real Median Household Income - Texas', 'earnings'),
#   'TXPCPI': ('Per Capita Personal Income - Texas', 'earnings'),
#   'TXPCE': ('Personal Consumption Expenditures: Total - Texas', 'consumption'),
#   'TXERET': ('Retail Trade Earnings - Texas', 'earnings'),
#   'UTUR': ('unemployment rate - Utah', 'unemployment'),
#   'STTMINWGUT': ('State Minimum Wage Rate - Utah', 'earnings'),
#   'UTUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Utah',
#    'housing'),
#   'UTSTHPI': ('All-Transactions House Price Index - Utah', 'housing'),
#   'UTNQGSP': ('Gross Domestic Product: All Industry Total - Utah', 'gdp'),
#   'MEHOINUSUTA672N': ('Real Median Household Income - Utah', 'earnings'),
#   'UTPCPI': ('Per Capita Personal Income - Utah', 'earnings'),
#   'UTPCE': ('Personal Consumption Expenditures: Total - Utah', 'consumption'),
#   'UTERET': ('Retail Trade Earnings - Utah', 'earnings'),
#   'VTUR': ('unemployment rate - Vermont', 'unemployment'),
#   'STTMINWGVT': ('State Minimum Wage Rate - Vermont', 'earnings'),
#   'VTUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Vermont',
#    'housing'),
#   'VTSTHPI': ('All-Transactions House Price Index - Vermont', 'housing'),
#   'VTNQGSP': ('Gross Domestic Product: All Industry Total - Vermont', 'gdp'),
#   'MEHOINUSVTA672N': ('Real Median Household Income - Vermont', 'earnings'),
#   'VTPCPI': ('Per Capita Personal Income - Vermont', 'earnings'),
#   'VTPCE': ('Personal Consumption Expenditures: Total - Vermont',
#    'consumption'),
#   'VTERET': ('Retail Trade Earnings - Vermont', 'earnings'),
#   'VAUR': ('unemployment rate - Virginia', 'unemployment'),
#   'STTMINWGVA': ('State Minimum Wage Rate - Virginia', 'earnings'),
#   'VAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Virginia',
#    'housing'),
#   'VASTHPI': ('All-Transactions House Price Index - Virginia', 'housing'),
#   'VANQGSP': ('Gross Domestic Product: All Industry Total - Virginia', 'gdp'),
#   'MEHOINUSVAA672N': ('Real Median Household Income - Virginia', 'earnings'),
#   'VAPCPI': ('Per Capita Personal Income - Virginia', 'earnings'),
#   'VAPCE': ('Personal Consumption Expenditures: Total - Virginia',
#    'consumption'),
#   'VAERET': ('Retail Trade Earnings - Virginia', 'earnings'),
#   'WAUR': ('unemployment rate - Washington', 'unemployment'),
#   'STTMINWGWA': ('State Minimum Wage Rate - Washington', 'earnings'),
#   'WAUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Washington',
#    'housing'),
#   'WASTHPI': ('All-Transactions House Price Index - Washington', 'housing'),
#   'WANQGSP': ('Gross Domestic Product: All Industry Total - Washington',
#    'gdp'),
#   'MEHOINUSWAA672N': ('Real Median Household Income - Washington', 'earnings'),
#   'WAPCPI': ('Per Capita Personal Income - Washington', 'earnings'),
#   'WAPCE': ('Personal Consumption Expenditures: Total - Washington',
#    'consumption'),
#   'WAERET': ('Retail Trade Earnings - Washington', 'earnings'),
#   'WVUR': ('unemployment rate - West Virginia', 'unemployment'),
#   'STTMINWGWV': ('State Minimum Wage Rate - West Virginia', 'earnings'),
#   'WVUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - West Virginia',
#    'housing'),
#   'WVSTHPI': ('All-Transactions House Price Index - West Virginia', 'housing'),
#   'WVNQGSP': ('Gross Domestic Product: All Industry Total - West Virginia',
#    'gdp'),
#   'MEHOINUSWVA672N': ('Real Median Household Income - West Virginia',
#    'earnings'),
#   'WVPCPI': ('Per Capita Personal Income - West Virginia', 'earnings'),
#   'WVPCE': ('Personal Consumption Expenditures: Total - West Virginia',
#    'consumption'),
#   'WVERET': ('Retail Trade Earnings - West Virginia', 'earnings'),
#   'WIUR': ('unemployment rate - Wisconsin', 'unemployment'),
#   'STTMINWGWI': ('State Minimum Wage Rate - Wisconsin', 'earnings'),
#   'WIUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Wisconsin',
#    'housing'),
#   'WISTHPI': ('All-Transactions House Price Index - Wisconsin', 'housing'),
#   'WINQGSP': ('Gross Domestic Product: All Industry Total - Wisconsin', 'gdp'),
#   'MEHOINUSWIA672N': ('Real Median Household Income - Wisconsin', 'earnings'),
#   'WIPCPI': ('Per Capita Personal Income - Wisconsin', 'earnings'),
#   'WIPCE': ('Personal Consumption Expenditures: Total - Wisconsin',
#    'consumption'),
#   'WIERET': ('Retail Trade Earnings - Wisconsin', 'earnings'),
#   'WYUR': ('unemployment rate - Wyoming', 'unemployment'),
#   'STTMINWGWY': ('State Minimum Wage Rate - Wyoming', 'earnings'),
#   'WYUCSFRCONDOSMSAMID': ('Zillow Home Value Index (ZHVI) for All Homes Including Single-Family Residences, Condos, and CO-OPs - Wyoming',
#    'housing'),
#   'WYSTHPI': ('All-Transactions House Price Index - Wyoming', 'housing'),
#   'WYNQGSP': ('Gross Domestic Product: All Industry Total - Wyoming', 'gdp'),
#   'MEHOINUSWYA672N': ('Real Median Household Income - Wyoming', 'earnings'),
#   'WYPCPI': ('Per Capita Personal Income - Wyoming', 'earnings'),
#   'WYPCE': ('Personal Consumption Expenditures: Total - Wyoming',
#    'consumption'),
#   'WYERET': ('Retail Trade Earnings - Wyoming', 'earnings')}}

# %%
etl.extract()

# %%
etl.load()

# %%
etl.datasets
# Out:
# [     metric_dt  metric metric_id        metric_desc  state_ind         topic
#  0   1948-01-01     3.4    UNRATE  Unemployment Rate          0  unemployment
#  1   1948-02-01     3.8    UNRATE  Unemployment Rate          0  unemployment
#  2   1948-03-01     4.0    UNRATE  Unemployment Rate          0  unemployment
#  3   1948-04-01     3.9    UNRATE  Unemployment Rate          0  unemployment
#  4   1948-05-01     3.5    UNRATE  Unemployment Rate          0  unemployment
#  ..         ...     ...       ...                ...        ...           ...
#  900 2023-01-01     3.4    UNRATE  Unemployment Rate          0  unemployment
#  901 2023-02-01     3.6    UNRATE  Unemployment Rate          0  unemployment
#  902 2023-03-01     3.5    UNRATE  Unemployment Rate          0  unemployment
#  903 2023-04-01     3.4    UNRATE  Unemployment Rate          0  unemployment
#  904 2023-05-01     3.7    UNRATE  Unemployment Rate          0  unemployment
#
#  [905 rows x 6 columns],
#       metric_dt  metric    metric_id  \
#  0   1972-01-01    11.2  LNS14000006
#  1   1972-02-01    11.2  LNS14000006
#  2   1972-03-01    10.7  LNS14000006
#  3   1972-04-01     9.8  LNS14000006
#  4   1972-05-01    10.2  LNS14000006
#  ..         ...     ...          ...
#  612 2023-01-01     5.4  LNS14000006
#  613 2023-02-01     5.7  LNS14000006
#  614 2023-03-01     5.0  LNS14000006
#  615 2023-04-01     4.7  LNS14000006
#  616 2023-05-01     5.6  LNS14000006
#
#                                         metric_desc  state_ind         topic
#  0    Unemployment Rate - Black or African American          0  unemployment
#  1    Unemployment Rate - Black or African American          0  unemployment
#  2    Unemployment Rate - Black or African American          0  unemployment
#  3    Unemployment Rate - Black or African American          0  unemployment
#  4    Unemployment Rate - Black or African American          0  unemployment
#  ..                                             ...        ...           ...
#  612  Unemployment Rate - Black or African American          0  unemployment
#  613  Unemployment Rate - Black or African American          0  unemployment
#  614  Unemployment Rate - Black or African American          0  unemployment
#  615  Unemployment Rate - Black or African American          0  unemployment
#  616  Unemployment Rate - Black or African American          0  unemployment
#
#  [617 rows x 6 columns],
#        metric_dt     metric metric_id                              metric_desc  \
#  0    1967-01-07  1134000.0      CCSA  Continued Claims (Insured Unemployment)
#  1    1967-01-14  1119000.0      CCSA  Continued Claims (Insured Unemployment)
#  2    1967-01-21  1119000.0      CCSA  Continued Claims (Insured Unemployment)
#  3    1967-01-28  1103000.0      CCSA  Continued Claims (Insured Unemployment)
#  4    1967-02-04  1131000.0      CCSA  Continued Claims (Insured Unemployment)
#  ...         ...        ...       ...                                      ...
#  2937 2023-04-22  1801000.0      CCSA  Continued Claims (Insured Unemployment)
#  2938 2023-04-29  1807000.0      CCSA  Continued Claims (Insured Unemployment)
#  2939 2023-05-06  1799000.0      CCSA  Continued Claims (Insured Unemployment)
#  2940 2023-05-13  1789000.0      CCSA  Continued Claims (Insured Unemployment)
#  2941 2023-05-20  1795000.0      CCSA  Continued Claims (Insured Unemployment)
#
#        state_ind         topic
#  0             0  unemployment
#  1             0  unemployment
#  2             0  unemployment
#  3             0  unemployment
#  4             0  unemployment
#  ...         ...           ...
#  2937          0  unemployment
#  2938          0  unemployment
#  2939          0  unemployment
#  2940          0  unemployment
#  2941          0  unemployment
#
#  [2942 rows x 6 columns],
#       metric_dt  metric metric_id               metric_desc  state_ind  \
#  0   1948-01-01     8.9  UEMPMEAN  Average Weeks Unemployed          0
#  1   1948-02-01     8.4  UEMPMEAN  Average Weeks Unemployed          0
#  2   1948-03-01     8.7  UEMPMEAN  Average Weeks Unemployed          0
#  3   1948-04-01     8.5  UEMPMEAN  Average Weeks Unemployed          0
#  4   1948-05-01     9.1  UEMPMEAN  Average Weeks Unemployed          0
#  ..         ...     ...       ...                       ...        ...
#  900 2023-01-01    20.4  UEMPMEAN  Average Weeks Unemployed          0
#  901 2023-02-01    19.3  UEMPMEAN  Average Weeks Unemployed          0
#  902 2023-03-01    19.5  UEMPMEAN  Average Weeks Unemployed          0
#  903 2023-04-01    20.9  UEMPMEAN  Average Weeks Unemployed          0
#  904 2023-05-01    21.2  UEMPMEAN  Average Weeks Unemployed          0
#
#              topic
#  0    unemployment
#  1    unemployment
#  2    unemployment
#  3    unemployment
#  4    unemployment
#  ..            ...
#  900  unemployment
#  901  unemployment
#  902  unemployment
#  903  unemployment
#  904  unemployment
#
#  [905 rows x 6 columns],
#       metric_dt  metric    metric_id                metric_desc  state_ind  \
#  0   1948-01-01     3.3  LNS14000002  Unemployment Rate - Women          0
#  1   1948-02-01     4.5  LNS14000002  Unemployment Rate - Women          0
#  2   1948-03-01     4.4  LNS14000002  Unemployment Rate - Women          0
#  3   1948-04-01     4.3  LNS14000002  Unemployment Rate - Women          0
#  4   1948-05-01     3.7  LNS14000002  Unemployment Rate - Women          0
#  ..         ...     ...          ...                        ...        ...
#  900 2023-01-01     3.3  LNS14000002  Unemployment Rate - Women          0
#  901 2023-02-01     3.5  LNS14000002  Unemployment Rate - Women          0
#  902 2023-03-01     3.4  LNS14000002  Unemployment Rate - Women          0
#  903 2023-04-01     3.3  LNS14000002  Unemployment Rate - Women          0
#  904 2023-05-01     3.6  LNS14000002  Unemployment Rate - Women          0
#
#              topic
#  0    unemployment
#  1    unemployment
#  2    unemployment
#  3    unemployment
#  4    unemployment
#  ..            ...
#  900  unemployment
#  901  unemployment
#  902  unemployment
#  903  unemployment
#  904  unemployment
#
#  [905 rows x 6 columns],
#       metric_dt  metric    metric_id                             metric_desc  \
#  0   1973-03-01     7.3  LNS14000009  Unemployment Rate - Hispanic or Latino
#  1   1973-04-01     7.9  LNS14000009  Unemployment Rate - Hispanic or Latino
#  2   1973-05-01     8.1  LNS14000009  Unemployment Rate - Hispanic or Latino
#  3   1973-06-01     7.9  LNS14000009  Unemployment Rate - Hispanic or Latino
#  4   1973-07-01     7.2  LNS14000009  Unemployment Rate - Hispanic or Latino
#  ..         ...     ...          ...                                     ...
#  598 2023-01-01     4.5  LNS14000009  Unemployment Rate - Hispanic or Latino
#  599 2023-02-01     5.3  LNS14000009  Unemployment Rate - Hispanic or Latino
#  600 2023-03-01     4.6  LNS14000009  Unemployment Rate - Hispanic or Latino
#  601 2023-04-01     4.4  LNS14000009  Unemployment Rate - Hispanic or Latino
#  602 2023-05-01     4.0  LNS14000009  Unemployment Rate - Hispanic or Latino
#
#       state_ind         topic
#  0            0  unemployment
#  1            0  unemployment
#  2            0  unemployment
#  3            0  unemployment
#  4            0  unemployment
#  ..         ...           ...
#  598          0  unemployment
#  599          0  unemployment
#  600          0  unemployment
#  601          0  unemployment
#  602          0  unemployment
#
#  [603 rows x 6 columns],
#       metric_dt  metric    metric_id              metric_desc  state_ind  \
#  0   1948-01-01     3.4  LNS14000001  Unemployment Rate - Men          0
#  1   1948-02-01     3.6  LNS14000001  Unemployment Rate - Men          0
#  2   1948-03-01     3.8  LNS14000001  Unemployment Rate - Men          0
#  3   1948-04-01     3.8  LNS14000001  Unemployment Rate - Men          0
#  4   1948-05-01     3.5  LNS14000001  Unemployment Rate - Men          0
#  ..         ...     ...          ...                      ...        ...
#  900 2023-01-01     3.6  LNS14000001  Unemployment Rate - Men          0
#  901 2023-02-01     3.6  LNS14000001  Unemployment Rate - Men          0
#  902 2023-03-01     3.6  LNS14000001  Unemployment Rate - Men          0
#  903 2023-04-01     3.5  LNS14000001  Unemployment Rate - Men          0
#  904 2023-05-01     3.7  LNS14000001  Unemployment Rate - Men          0
#
#              topic
#  0    unemployment
#  1    unemployment
#  2    unemployment
#  3    unemployment
#  4    unemployment
#  ..            ...
#  900  unemployment
#  901  unemployment
#  902  unemployment
#  903  unemployment
#  904  unemployment
#
#  [905 rows x 6 columns],
#       metric_dt  metric    metric_id                metric_desc  state_ind  \
#  0   1954-01-01     4.5  LNS14000003  Unemployment Rate - White          0
#  1   1954-02-01     4.9  LNS14000003  Unemployment Rate - White          0
#  2   1954-03-01     5.0  LNS14000003  Unemployment Rate - White          0
#  3   1954-04-01     5.5  LNS14000003  Unemployment Rate - White          0
#  4   1954-05-01     5.3  LNS14000003  Unemployment Rate - White          0
#  ..         ...     ...          ...                        ...        ...
#  828 2023-01-01     3.1  LNS14000003  Unemployment Rate - White          0
#  829 2023-02-01     3.2  LNS14000003  Unemployment Rate - White          0
#  830 2023-03-01     3.2  LNS14000003  Unemployment Rate - White          0
#  831 2023-04-01     3.1  LNS14000003  Unemployment Rate - White          0
#  832 2023-05-01     3.3  LNS14000003  Unemployment Rate - White          0
#
#              topic
#  0    unemployment
#  1    unemployment
#  2    unemployment
#  3    unemployment
#  4    unemployment
#  ..            ...
#  828  unemployment
#  829  unemployment
#  830  unemployment
#  831  unemployment
#  832  unemployment
#
#  [833 rows x 6 columns],
#       metric_dt  metric metric_id                            metric_desc  \
#  0   1948-01-01   128.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  1   1948-02-01   121.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  2   1948-03-01   110.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  3   1948-04-01   109.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  4   1948-05-01   109.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  ..         ...     ...       ...                                    ...
#  900 2023-01-01  1111.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  901 2023-02-01  1057.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  902 2023-03-01  1104.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  903 2023-04-01  1156.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#  904 2023-05-01  1188.0  UEMP27OV  Number Unemployed for 27 Weeks & over
#
#       state_ind         topic
#  0            0  unemployment
#  1            0  unemployment
#  2            0  unemployment
#  3            0  unemployment
#  4            0  unemployment
#  ..         ...           ...
#  900          0  unemployment
#  901          0  unemployment
#  902          0  unemployment
#  903          0  unemployment
#  904          0  unemployment
#
#  [905 rows x 6 columns]]
